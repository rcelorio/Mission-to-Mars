# %%
#import dependencies
from flask import Flask, render_template
from flask_pymongo import PyMongo
import scraping
# Out:
# /Users/rfcelorio/anaconda3/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,

# %%
#setup flask
app = Flask(__name__)

# Use flask_pymongo to set up mongo connection
app.config["MONGO_URI"] = "mongodb://localhost:27017/mars_app"
mongo = PyMongo(app)

# %%
@app.route("/")
def index():
   mars = mongo.db.mars.find_one()
   return render_template("index.html", mars=mars)

@app.route("/scrape")
def scrape():
   mars = mongo.db.mars
   mars_data = scraping.scrape_all()
   mars.update({}, mars_data, upsert=True)
   return "Scraping Successful!"

# %%
  print(scrape_all())
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2020-03-20 10:44:18,052] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:18] "GET / HTTP/1.1" 500 -
# [2020-03-20 10:44:19,380] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:19] "GET / HTTP/1.1" 500 -
# [2020-03-20 10:44:20,663] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:20] "GET / HTTP/1.1" 500 -
# [2020-03-20 10:44:21,587] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:21] "GET / HTTP/1.1" 500 -
# [2020-03-20 10:44:21,767] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:21] "GET / HTTP/1.1" 500 -
# [2020-03-20 10:44:22,181] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:22] "GET / HTTP/1.1" 500 -
# [2020-03-20 10:44:22,598] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-be498bca71bd>", line 4, in index
#     return render_template("index.html", mars=mars)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/rfcelorio/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [20/Mar/2020 10:44:22] "GET / HTTP/1.1" 500 -
